# %% [markdown]
# # 1.2 Query of the Archives Collection

# %% [markdown]
# This example illustartes the V4 Channel Archiver interface
# for getting the information about included archives, such as
# * key: numerical key
# * name: name
# * path: path to the index file
#
# This data structure is designed after the original XML-RPC protocol
# (see, for example, 4.4.2 archiver.archives, Channel Archiver Manual, 2006)

# %% [markdown]
# First, we import the necessary modules from the python standard library, numpy, pandas, and eapy.

# %%
#import the standard modules
import sys
import pdb
import time
from datetime import timedelta, datetime, tzinfo

#import numpy, pandas
sys.path.insert(1, '/home/malitsky/opt/python/lib/python2.7/site-packages')
import numpy as np
import pandas as pd

#import the eapy module
import eapy

# %% [markdown]
# and define parameters of the EPICS V4 RPC service, such as a server address, channel name and timeout.

# %%
chName = "ea4.rpc:classic"; # service based on the original index files
timeout = 3.0;

# %% [markdown]
# Then, we need to start a session for connecting it with the middle layer service and creating a session-specific context.

# %%
session = eapy.Session.createSession();
session.open(chName, timeout);

# %% [markdown]
# According to the MongoDB-oriented model, the corresponding information is located in the 'archives' collection.

# %%
archivesProxy = session.createProxy("archives");
archivesCollect = archivesProxy.collect(timeout);

# %% [markdown]
# The collect method returns a structure including a query status and a collection of documents. First, let's check the query status (int type, string message, string callTree).

# %%
print archivesCollect['status']['type']
# Out:
# 0

# %% [markdown]
# There are four types of query statuses: 0 - OK, 1 - Warning, 2 - Error, 3 - Fatal. If the query is OK, we can extract an array of documents.

# %%
archives = archivesCollect['docs']

# %% [markdown]
# According to the MongoDB-oriented model, any collections are heterogeneous. As a result, it is represented by the dynamic structure with size and index fields, like 0, 1, etc.

# %%
archivesNP = np.zeros((archives['size'],),dtype=[('key', 'i4'),('name', 'a50'), ('path', 'a70')])
for i in range(archives['size']):
    archive = archives[str(i)];
    archivesNP[i] = (archive['key'], archive['name'], archive['path'])
archivesDF = pd.DataFrame(archivesNP);
archivesDF
# Out:
#       key                name  \
# 0       0     bakeout/Current
# 1    6060        bakeout/2015
# 2    8109      vacuum/Current
# 3    9965       beaminst/2014
# 4   10576    controls/Current
# 5   13020         eps/Current
# 6   13687      optics/Current
# 7   21052       beaminst/2015
# 8   21261    frontend/Current
# 9   23238        bakeout/2014
# 10  23796         vacuum/2014
# 11  24463       frontend/2014
# 12  25469       controls/2014
# 13  28085             sr/2015
# 14  28366            eps/2015
# 15  29219      scaler/Current
# 16  49926       controls/2015
# 17  50077             sr/2014
# 18  50454         vacuum/2015
# 19  50658         scaler/2014
# 20  52474            rga/2014
# 21  52954         rga/Current
# 22  54602             id/2014
# 23  55110     endstation/2015
# 24  55523         optics/2014
# 25  58379       frontend/2015
# 26  58887            eps/2014
# 27  59810             id/2015
# 28  61363          id/Current
# 29  62023     endstation/2014
# 30  62172         scaler/2015
# 31  62627            rga/2015
# 32  64293          sr/Current
# 33  64455    beaminst/Current
# 34  64653  endstation/Current
# 35  64955         optics/2015
#
#                                                 path
# 0        /DATA/channelarchiver/bakeout/current_index
# 1      /DATA/channelarchiver/bakeout/2015/year_index
# 2         /DATA/channelarchiver/vacuum/current_index
# 3     /DATA/channelarchiver/beaminst/2014/year_index
# 4       /DATA/channelarchiver/controls/current_index
# 5            /DATA/channelarchiver/eps/current_index
# 6         /DATA/channelarchiver/optics/current_index
# 7     /DATA/channelarchiver/beaminst/2015/year_index
# 8       /DATA/channelarchiver/frontend/current_index
# 9      /DATA/channelarchiver/bakeout/2014/year_index
# 10      /DATA/channelarchiver/vacuum/2014/year_index
# 11    /DATA/channelarchiver/frontend/2014/year_index
# 12    /DATA/channelarchiver/controls/2014/year_index
# 13          /DATA/channelarchiver/sr/2015/year_index
# 14         /DATA/channelarchiver/eps/2015/year_index
# 15        /DATA/channelarchiver/scaler/current_index
# 16    /DATA/channelarchiver/controls/2015/year_index
# 17          /DATA/channelarchiver/sr/2014/year_index
# 18      /DATA/channelarchiver/vacuum/2015/year_index
# 19      /DATA/channelarchiver/scaler/2014/year_index
# 20         /DATA/channelarchiver/rga/2014/year_index
# 21           /DATA/channelarchiver/rga/current_index
# 22          /DATA/channelarchiver/id/2014/year_index
# 23  /DATA/channelarchiver/endstation/2015/year_index
# 24      /DATA/channelarchiver/optics/2014/year_index
# 25    /DATA/channelarchiver/frontend/2015/year_index
# 26         /DATA/channelarchiver/eps/2014/year_index
# 27          /DATA/channelarchiver/id/2015/year_index
# 28            /DATA/channelarchiver/id/current_index
# 29  /DATA/channelarchiver/endstation/2014/year_index
# 30      /DATA/channelarchiver/scaler/2015/year_index
# 31         /DATA/channelarchiver/rga/2015/year_index
# 32            /DATA/channelarchiver/sr/current_index
# 33      /DATA/channelarchiver/beaminst/current_index
# 34    /DATA/channelarchiver/endstation/current_index
# 35      /DATA/channelarchiver/optics/2015/year_index

# %%
session.close();
